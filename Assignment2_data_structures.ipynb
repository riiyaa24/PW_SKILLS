# %% [markdown]
# **Question 1**
#
# To comment code in Python 3.x version, two types of code can be used which is single line comment and multi-line comment. For single line comment use a hash(#) symbol at the starting of the line of code. For multi-line comment use triple quotation marks(""" --- """) at the starting and ending of the lines which want to be comment.

# %% [markdown]
# **Question 2**
#
# Variables are containers for storing data values of different data types. A variable is created the moment you first assign a value to it.
#
# x = 5
#
# y = "John"
#
# Variables in python do not need to be declared with any paticular type, and can even change type after they have been set. If you want to specify or change the data type of variable, typecasting can be done.
# Assignment operator is used to assign values to the variables.

# %% [markdown]
# **Question 3**
#
# In python to one data type to another, we use typecasting. Python is an object-oriented language, and as such it uses classes to define data types, including its primitive types. It changes into desired data type.
# While taking input from user using the input() function the data type which is accepted as input is string and it is not always the case that user needs to give string data type, it can also be integer or float or boolean. To do that typecasting can e used.
#
# eg. mobile_no = int(input())
#
# this accepts mobile no in integer for data type.

# %% [markdown]
# **Question 4**
#
# To write and execute a Python script from the command line, you can follow these steps:
#
# 1. Open a text editor and create a new file. For example, you can use a plain text editor like Notepad (Windows), TextEdit (Mac), or any code editor like Visual Studio Code, Atom, or Sublime Text.
#
# 2. Write your Python code in the text editor. For example, let's say you want to create a simple script that prints "Hello, World!" to the console. Your code would look like this:
#
# ```python
# print("Hello, World!")
# ```
#
# 3. Save the file with a .py extension. Choose a meaningful name for your script, and save it with the .py extension. For example, you can save the file as `hello.py`.
#
# 4. Open the command line or terminal on your operating system. The method for opening the command line or terminal depends on your operating system:
#
#    - On Windows: Press `Win + R`, type `cmd`, and press Enter.
#    - On macOS: Press `Cmd + Space`, type `terminal`, and press Enter.
#    - On Linux: Press `Ctrl + Alt + T`.
#
# 5. Navigate to the directory where you saved the Python script using the `cd` command. For example, if you saved the script in the Documents folder, you would use the following command:
#
#    ```
#    cd Documents
#    ```
#
# 6. Execute the Python script by running the `python` command followed by the script's filename. For example, if your script is named `hello.py`, you would use the following command:
#
#    ```
#    python hello.py
#   ```

# %%
#Question 5

my_list = [1,2,3,4,5]
sub_list = my_list[1:3]
print(sub_list)
# Out:
# [2, 3]

# %% [markdown]
# Question 6
#
# Complex number in mathematics is a number that can be expressed in the form "a + bi," where "a" and "b" are real numbers, and "i" is the imaginary unit defined by the property that its square is equal to -1 (i^2 = -1). In python the complex part is expressed in 'j'.
#
# In python, complex numbers can be represented in the following form.
#
# 5 + 4j

# %%
#Question 7
""" to declare a variable in python the name should be properly assigned. """
age = 25

# %%
#Question 8
price = 9.99
type(price)
# Out:
# float

# %%
#Question 9
name = "Riya Dhanduke"
print(name)
# Out:
# Riya Dhanduke

# %%
#Question 10
stn = "Hello, World!"
new_stn = stn[7:12]
print(new_stn)
# Out:
# World

# %%
#Question 11
is_student = True
type(is_student)
# Out:
# bool
